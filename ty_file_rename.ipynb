# %%
import os
import shutil
from pathlib import Path

def decimal_to_base26(n):
    """将十进制数字转换为26进制字母表示"""
    result = ""
    while n > 0:
        n, remainder = divmod(n - 1, 26)
        result = chr(remainder + ord('a')) + result
    return result

def move_and_rename_images(directory):
    """
    递归遍历指定目录，将所有图片文件移动到该目录并重命名。
    完成后，根据成功处理的文件记录，删除非图片文件和未成功处理的图片及空目录。
    同时记录操作到操作日志文件。
    
    图片文件被重命名为基于26进制的字母组合，如'a', 'b', ..., 'z', 'aa', 'ab', ...
    
    参数:
    directory (str or Path): 目标目录路径
    """
    counter = 0
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']
    successful_files = set()
    operation_log_path = Path(directory) / "operation_log.txt"

    target_dir = Path(directory)
    if not target_dir.is_dir():
        print(f"目录不存在: {directory}")
        return

    failed_counter = 0  # 记录失败操作的文件数量

    with open(operation_log_path, 'w') as log_file:
        for root, dirs, files in os.walk(directory, topdown=False):
            for name in files:
                if any(name.lower().endswith(ext) for ext in image_extensions):
                    counter += 1
                    source_path = Path(root) / name
                    extension = source_path.suffix
                    new_name = decimal_to_base26(counter)
                    target_path = target_dir / f"{new_name}{extension}"
                    
                    try:
                        shutil.move(str(source_path), str(target_path))
                        print(f"移动并重命名: {source_path} -> {target_path}")
                        successful_files.add(new_name + extension)  # 更新为包含扩展名
                        log_file.write(f"{source_path},{target_path}\n")
                    except Exception as e:
                        print(f"处理文件{source_path}时发生错误: {e}")
                        failed_counter += 1  # 失败操作的文件数量加一

    def clean_non_image_or_unprocessed_files_and_dirs(path, successful_files_set):
        for item in path.iterdir():
            if item.is_file():
                if item.suffix.lower() not in image_extensions or item.name not in successful_files_set:
                    try:
                        if item != operation_log_path:
                            item.unlink()
                            print(f"删除文件: {item}")
                    except Exception as e:
                        print(f"删除文件{item}时发生错误: {e}")
            elif item.is_dir():
                clean_non_image_or_unprocessed_files_and_dirs(item, successful_files_set)
                try:
                    if not any(item.iterdir()) and item != target_dir:
                        item.rmdir()
                        print(f"删除空目录: {item}")
                except Exception as e:
                    print(f"删除空目录{item}时发生错误: {e}")
                    
    clean_non_image_or_unprocessed_files_and_dirs(target_dir, successful_files)

    # 输出成功操作的文件数量和失败操作的文件数量
    total_files = counter
    successful_files_count = len(successful_files)
    failed_files_count = failed_counter
    print(f"处理完成。成功操作文件数量: {successful_files_count}，失败操作文件数量: {failed_files_count}，总共操作文件数量: {total_files}")

def reverse_operations(directory):
    """
    逆向操作，根据操作日志文件中的记录还原文件至原始位置。
    修正：正确处理源路径和目标路径，确保文件从新位置移回到原始位置。
    """
    operation_log_path = Path(directory) / "operation_log.txt"
    if not operation_log_path.exists():
        print("操作日志文件不存在，无法进行逆向操作。")
        return
    
    with open(operation_log_path, 'r') as log_file:
        for line in log_file:
            source_path_str, target_path_str = line.strip().split(',')
            source_path = Path(source_path_str)  # 原始路径
            target_path = Path(target_path_str)     # 当前路径（正向操作后的位置）
            
            try:
                # 确保源路径的父目录存在，因为我们要将文件移回那里
                source_path.parent.mkdir(parents=True, exist_ok=True)
                shutil.move(str(target_path), str(source_path))  # 从当前路径移回原始路径
                print(f"逆向操作完成: {target_path} -> {source_path}")
            except FileNotFoundError:
                print(f"文件{target_path}不存在，跳过逆向操作。")
            except Exception as e:
                print(f"逆向操作时发生错误: {e}")

if __name__ == "__main__":
    target_directory = "/Volumes/192.168.1.173/pic/jjw"
    print("开始处理...")
    move_and_rename_images(target_directory)
    # 可以手动调用逆向操作，但需谨慎处理
    # reverse_operations(target_directory)
# Out:
# 开始处理...
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/a.jpeg -> /Volumes/192.168.1.173/pic/jjw/a.jpeg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/b.jpg -> /Volumes/192.168.1.173/pic/jjw/b.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/c.jpg -> /Volumes/192.168.1.173/pic/jjw/c.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/d.jpeg -> /Volumes/192.168.1.173/pic/jjw/d.jpeg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/e.jpg -> /Volumes/192.168.1.173/pic/jjw/e.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/f.jpeg -> /Volumes/192.168.1.173/pic/jjw/f.jpeg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/g.jpg -> /Volumes/192.168.1.173/pic/jjw/g.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/h.jpg -> /Volumes/192.168.1.173/pic/jjw/h.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/i.jpg -> /Volumes/192.168.1.173/pic/jjw/i.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/j.jpg -> /Volumes/192.168.1.173/pic/jjw/j.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/k.jpg -> /Volumes/192.168.1.173/pic/jjw/k.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/l.jpg -> /Volumes/192.168.1.173/pic/jjw/l.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/m.jpg -> /Volumes/192.168.1.173/pic/jjw/m.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/n.jpg -> /Volumes/192.168.1.173/pic/jjw/n.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/o.jpg -> /Volumes/192.168.1.173/pic/jjw/o.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/p.jpg -> /Volumes/192.168.1.173/pic/jjw/p.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/q.jpg -> /Volumes/192.168.1.173/pic/jjw/q.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/r.jpg -> /Volumes/192.168.1.173/pic/jjw/r.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/s.jpg -> /Volumes/192.168.1.173/pic/jjw/s.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/t.jpg -> /Volumes/192.168.1.173/pic/jjw/t.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/u.jpg -> /Volumes/192.168.1.173/pic/jjw/u.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/v.jpg -> /Volumes/192.168.1.173/pic/jjw/v.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/w.jpg -> /Volumes/192.168.1.173/pic/jjw/w.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/x.jpg -> /Volumes/192.168.1.173/pic/jjw/x.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/y.jpg -> /Volumes/192.168.1.173/pic/jjw/y.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/z.jpg -> /Volumes/192.168.1.173/pic/jjw/z.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/aa.jpg -> /Volumes/192.168.1.173/pic/jjw/aa.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ab.jpg -> /Volumes/192.168.1.173/pic/jjw/ab.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ac.jpg -> /Volumes/192.168.1.173/pic/jjw/ac.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ad.jpg -> /Volumes/192.168.1.173/pic/jjw/ad.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ae.jpg -> /Volumes/192.168.1.173/pic/jjw/ae.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/af.jpg -> /Volumes/192.168.1.173/pic/jjw/af.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ag.jpg -> /Volumes/192.168.1.173/pic/jjw/ag.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ah.jpg -> /Volumes/192.168.1.173/pic/jjw/ah.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ai.jpg -> /Volumes/192.168.1.173/pic/jjw/ai.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/aj.jpg -> /Volumes/192.168.1.173/pic/jjw/aj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ak.jpg -> /Volumes/192.168.1.173/pic/jjw/ak.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/al.jpg -> /Volumes/192.168.1.173/pic/jjw/al.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/am.jpg -> /Volumes/192.168.1.173/pic/jjw/am.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/an.jpg -> /Volumes/192.168.1.173/pic/jjw/an.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ao.jpg -> /Volumes/192.168.1.173/pic/jjw/ao.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ap.jpg -> /Volumes/192.168.1.173/pic/jjw/ap.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/aq.jpg -> /Volumes/192.168.1.173/pic/jjw/aq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ar.jpg -> /Volumes/192.168.1.173/pic/jjw/ar.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/as.jpg -> /Volumes/192.168.1.173/pic/jjw/as.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/at.jpg -> /Volumes/192.168.1.173/pic/jjw/at.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/au.jpg -> /Volumes/192.168.1.173/pic/jjw/au.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/av.jpg -> /Volumes/192.168.1.173/pic/jjw/av.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/aw.jpg -> /Volumes/192.168.1.173/pic/jjw/aw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ax.jpg -> /Volumes/192.168.1.173/pic/jjw/ax.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ay.jpg -> /Volumes/192.168.1.173/pic/jjw/ay.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/az.jpg -> /Volumes/192.168.1.173/pic/jjw/az.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ba.jpg -> /Volumes/192.168.1.173/pic/jjw/ba.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bb.jpg -> /Volumes/192.168.1.173/pic/jjw/bb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bc.jpg -> /Volumes/192.168.1.173/pic/jjw/bc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bd.jpg -> /Volumes/192.168.1.173/pic/jjw/bd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/be.jpg -> /Volumes/192.168.1.173/pic/jjw/be.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bf.jpg -> /Volumes/192.168.1.173/pic/jjw/bf.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bg.jpg -> /Volumes/192.168.1.173/pic/jjw/bg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bh.jpg -> /Volumes/192.168.1.173/pic/jjw/bh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bi.jpg -> /Volumes/192.168.1.173/pic/jjw/bi.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bj.jpg -> /Volumes/192.168.1.173/pic/jjw/bj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bk.jpg -> /Volumes/192.168.1.173/pic/jjw/bk.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bl.jpg -> /Volumes/192.168.1.173/pic/jjw/bl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bm.jpg -> /Volumes/192.168.1.173/pic/jjw/bm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bn.jpg -> /Volumes/192.168.1.173/pic/jjw/bn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bo.jpg -> /Volumes/192.168.1.173/pic/jjw/bo.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bp.jpg -> /Volumes/192.168.1.173/pic/jjw/bp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bq.jpg -> /Volumes/192.168.1.173/pic/jjw/bq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/br.jpg -> /Volumes/192.168.1.173/pic/jjw/br.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bs.jpg -> /Volumes/192.168.1.173/pic/jjw/bs.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bt.jpg -> /Volumes/192.168.1.173/pic/jjw/bt.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bu.jpg -> /Volumes/192.168.1.173/pic/jjw/bu.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bv.jpg -> /Volumes/192.168.1.173/pic/jjw/bv.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bw.jpg -> /Volumes/192.168.1.173/pic/jjw/bw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bx.jpg -> /Volumes/192.168.1.173/pic/jjw/bx.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/by.jpg -> /Volumes/192.168.1.173/pic/jjw/by.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/bz.jpg -> /Volumes/192.168.1.173/pic/jjw/bz.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ca.jpg -> /Volumes/192.168.1.173/pic/jjw/ca.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cb.jpg -> /Volumes/192.168.1.173/pic/jjw/cb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cc.jpg -> /Volumes/192.168.1.173/pic/jjw/cc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cd.jpg -> /Volumes/192.168.1.173/pic/jjw/cd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ce.jpg -> /Volumes/192.168.1.173/pic/jjw/ce.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cf.jpg -> /Volumes/192.168.1.173/pic/jjw/cf.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cg.jpg -> /Volumes/192.168.1.173/pic/jjw/cg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ch.jpg -> /Volumes/192.168.1.173/pic/jjw/ch.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ci.jpg -> /Volumes/192.168.1.173/pic/jjw/ci.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cj.jpg -> /Volumes/192.168.1.173/pic/jjw/cj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ck.jpg -> /Volumes/192.168.1.173/pic/jjw/ck.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cl.jpg -> /Volumes/192.168.1.173/pic/jjw/cl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cm.jpg -> /Volumes/192.168.1.173/pic/jjw/cm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cn.jpg -> /Volumes/192.168.1.173/pic/jjw/cn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/co.jpg -> /Volumes/192.168.1.173/pic/jjw/co.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cp.jpg -> /Volumes/192.168.1.173/pic/jjw/cp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cq.jpg -> /Volumes/192.168.1.173/pic/jjw/cq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cr.jpg -> /Volumes/192.168.1.173/pic/jjw/cr.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cs.jpg -> /Volumes/192.168.1.173/pic/jjw/cs.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ct.jpg -> /Volumes/192.168.1.173/pic/jjw/ct.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cu.jpg -> /Volumes/192.168.1.173/pic/jjw/cu.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cv.jpg -> /Volumes/192.168.1.173/pic/jjw/cv.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cw.jpg -> /Volumes/192.168.1.173/pic/jjw/cw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cx.jpg -> /Volumes/192.168.1.173/pic/jjw/cx.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cy.jpg -> /Volumes/192.168.1.173/pic/jjw/cy.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/cz.jpg -> /Volumes/192.168.1.173/pic/jjw/cz.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/da.jpg -> /Volumes/192.168.1.173/pic/jjw/da.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/db.jpg -> /Volumes/192.168.1.173/pic/jjw/db.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dc.jpg -> /Volumes/192.168.1.173/pic/jjw/dc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dd.jpg -> /Volumes/192.168.1.173/pic/jjw/dd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/de.jpg -> /Volumes/192.168.1.173/pic/jjw/de.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/df.jpg -> /Volumes/192.168.1.173/pic/jjw/df.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dg.jpg -> /Volumes/192.168.1.173/pic/jjw/dg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dh.jpg -> /Volumes/192.168.1.173/pic/jjw/dh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/di.jpg -> /Volumes/192.168.1.173/pic/jjw/di.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dj.jpg -> /Volumes/192.168.1.173/pic/jjw/dj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dk.jpg -> /Volumes/192.168.1.173/pic/jjw/dk.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dl.jpg -> /Volumes/192.168.1.173/pic/jjw/dl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dm.jpg -> /Volumes/192.168.1.173/pic/jjw/dm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dn.jpg -> /Volumes/192.168.1.173/pic/jjw/dn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/do.jpg -> /Volumes/192.168.1.173/pic/jjw/do.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dp.jpg -> /Volumes/192.168.1.173/pic/jjw/dp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dq.jpg -> /Volumes/192.168.1.173/pic/jjw/dq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dr.jpg -> /Volumes/192.168.1.173/pic/jjw/dr.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ds.jpg -> /Volumes/192.168.1.173/pic/jjw/ds.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dt.jpg -> /Volumes/192.168.1.173/pic/jjw/dt.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/du.jpg -> /Volumes/192.168.1.173/pic/jjw/du.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dv.jpg -> /Volumes/192.168.1.173/pic/jjw/dv.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dw.jpg -> /Volumes/192.168.1.173/pic/jjw/dw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dx.jpg -> /Volumes/192.168.1.173/pic/jjw/dx.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dy.jpg -> /Volumes/192.168.1.173/pic/jjw/dy.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/dz.jpg -> /Volumes/192.168.1.173/pic/jjw/dz.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ea.jpg -> /Volumes/192.168.1.173/pic/jjw/ea.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eb.jpg -> /Volumes/192.168.1.173/pic/jjw/eb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ec.jpg -> /Volumes/192.168.1.173/pic/jjw/ec.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ed.jpg -> /Volumes/192.168.1.173/pic/jjw/ed.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ee.jpg -> /Volumes/192.168.1.173/pic/jjw/ee.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ef.jpg -> /Volumes/192.168.1.173/pic/jjw/ef.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eg.jpg -> /Volumes/192.168.1.173/pic/jjw/eg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eh.jpg -> /Volumes/192.168.1.173/pic/jjw/eh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ei.jpg -> /Volumes/192.168.1.173/pic/jjw/ei.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ej.jpg -> /Volumes/192.168.1.173/pic/jjw/ej.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ek.jpg -> /Volumes/192.168.1.173/pic/jjw/ek.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/el.jpg -> /Volumes/192.168.1.173/pic/jjw/el.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/em.jpg -> /Volumes/192.168.1.173/pic/jjw/em.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/en.jpg -> /Volumes/192.168.1.173/pic/jjw/en.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eo.jpg -> /Volumes/192.168.1.173/pic/jjw/eo.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ep.jpg -> /Volumes/192.168.1.173/pic/jjw/ep.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eq.jpg -> /Volumes/192.168.1.173/pic/jjw/eq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/er.jpg -> /Volumes/192.168.1.173/pic/jjw/er.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/es.jpg -> /Volumes/192.168.1.173/pic/jjw/es.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/et.jpg -> /Volumes/192.168.1.173/pic/jjw/et.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/eu.jpg -> /Volumes/192.168.1.173/pic/jjw/eu.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ev.jpg -> /Volumes/192.168.1.173/pic/jjw/ev.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ew.jpg -> /Volumes/192.168.1.173/pic/jjw/ew.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ex.jpg -> /Volumes/192.168.1.173/pic/jjw/ex.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ey.jpg -> /Volumes/192.168.1.173/pic/jjw/ey.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ez.jpg -> /Volumes/192.168.1.173/pic/jjw/ez.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fa.jpg -> /Volumes/192.168.1.173/pic/jjw/fa.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fb.jpg -> /Volumes/192.168.1.173/pic/jjw/fb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fc.jpg -> /Volumes/192.168.1.173/pic/jjw/fc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fd.jpg -> /Volumes/192.168.1.173/pic/jjw/fd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fe.jpg -> /Volumes/192.168.1.173/pic/jjw/fe.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ff.jpg -> /Volumes/192.168.1.173/pic/jjw/ff.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fg.jpg -> /Volumes/192.168.1.173/pic/jjw/fg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fh.jpg -> /Volumes/192.168.1.173/pic/jjw/fh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fi.jpg -> /Volumes/192.168.1.173/pic/jjw/fi.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fj.jpg -> /Volumes/192.168.1.173/pic/jjw/fj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fk.jpg -> /Volumes/192.168.1.173/pic/jjw/fk.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fl.jpg -> /Volumes/192.168.1.173/pic/jjw/fl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fm.jpg -> /Volumes/192.168.1.173/pic/jjw/fm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fn.jpg -> /Volumes/192.168.1.173/pic/jjw/fn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fo.jpg -> /Volumes/192.168.1.173/pic/jjw/fo.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fp.jpg -> /Volumes/192.168.1.173/pic/jjw/fp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fq.jpg -> /Volumes/192.168.1.173/pic/jjw/fq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fr.jpg -> /Volumes/192.168.1.173/pic/jjw/fr.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fs.jpg -> /Volumes/192.168.1.173/pic/jjw/fs.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ft.jpg -> /Volumes/192.168.1.173/pic/jjw/ft.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fu.jpg -> /Volumes/192.168.1.173/pic/jjw/fu.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fv.jpg -> /Volumes/192.168.1.173/pic/jjw/fv.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fw.jpg -> /Volumes/192.168.1.173/pic/jjw/fw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fx.jpg -> /Volumes/192.168.1.173/pic/jjw/fx.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fy.jpg -> /Volumes/192.168.1.173/pic/jjw/fy.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/fz.jpg -> /Volumes/192.168.1.173/pic/jjw/fz.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ga.jpg -> /Volumes/192.168.1.173/pic/jjw/ga.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gb.jpg -> /Volumes/192.168.1.173/pic/jjw/gb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gc.jpg -> /Volumes/192.168.1.173/pic/jjw/gc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gd.jpg -> /Volumes/192.168.1.173/pic/jjw/gd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ge.jpg -> /Volumes/192.168.1.173/pic/jjw/ge.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gf.jpg -> /Volumes/192.168.1.173/pic/jjw/gf.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gg.jpg -> /Volumes/192.168.1.173/pic/jjw/gg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gh.jpg -> /Volumes/192.168.1.173/pic/jjw/gh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gi.jpg -> /Volumes/192.168.1.173/pic/jjw/gi.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gj.jpg -> /Volumes/192.168.1.173/pic/jjw/gj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gk.jpg -> /Volumes/192.168.1.173/pic/jjw/gk.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gl.jpg -> /Volumes/192.168.1.173/pic/jjw/gl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gm.jpg -> /Volumes/192.168.1.173/pic/jjw/gm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gn.jpg -> /Volumes/192.168.1.173/pic/jjw/gn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/go.jpg -> /Volumes/192.168.1.173/pic/jjw/go.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gp.jpg -> /Volumes/192.168.1.173/pic/jjw/gp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gq.jpg -> /Volumes/192.168.1.173/pic/jjw/gq.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gr.jpg -> /Volumes/192.168.1.173/pic/jjw/gr.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gs.jpg -> /Volumes/192.168.1.173/pic/jjw/gs.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gt.gif -> /Volumes/192.168.1.173/pic/jjw/gt.gif
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gu.jpg -> /Volumes/192.168.1.173/pic/jjw/gu.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gv.png -> /Volumes/192.168.1.173/pic/jjw/gv.png
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gw.jpg -> /Volumes/192.168.1.173/pic/jjw/gw.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gx.jpg -> /Volumes/192.168.1.173/pic/jjw/gx.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gy.jpg -> /Volumes/192.168.1.173/pic/jjw/gy.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/gz.jpg -> /Volumes/192.168.1.173/pic/jjw/gz.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ha.jpg -> /Volumes/192.168.1.173/pic/jjw/ha.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hb.jpg -> /Volumes/192.168.1.173/pic/jjw/hb.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hc.jpg -> /Volumes/192.168.1.173/pic/jjw/hc.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hd.jpg -> /Volumes/192.168.1.173/pic/jjw/hd.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/he.jpg -> /Volumes/192.168.1.173/pic/jjw/he.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hf.jpg -> /Volumes/192.168.1.173/pic/jjw/hf.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hg.jpg -> /Volumes/192.168.1.173/pic/jjw/hg.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hh.jpg -> /Volumes/192.168.1.173/pic/jjw/hh.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hi.jpg -> /Volumes/192.168.1.173/pic/jjw/hi.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hj.jpg -> /Volumes/192.168.1.173/pic/jjw/hj.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hk.jpg -> /Volumes/192.168.1.173/pic/jjw/hk.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hl.jpg -> /Volumes/192.168.1.173/pic/jjw/hl.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hm.jpg -> /Volumes/192.168.1.173/pic/jjw/hm.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hn.jpg -> /Volumes/192.168.1.173/pic/jjw/hn.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/ho.jpg -> /Volumes/192.168.1.173/pic/jjw/ho.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hp.jpg -> /Volumes/192.168.1.173/pic/jjw/hp.jpg
# 移动并重命名: /Volumes/192.168.1.173/pic/jjw/hq.jpg -> /Volumes/192.168.1.173/pic/jjw/hq.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 111
#     109 target_directory = "/Volumes/192.168.1.173/pic/jjw"
#     110 print("开始处理...")
# --> 111 move_and_rename_images(target_directory)
#     112 # 可以手动调用逆向操作，但需谨慎处理
#     113 # reverse_operations(target_directory)
#
# Cell In[5], line 47, in move_and_rename_images(directory)
#      44 target_path = target_dir / f"{new_name}{extension}"
#      46 try:
# ---> 47     shutil.move(str(source_path), str(target_path))
#      48     print(f"移动并重命名: {source_path} -> {target_path}")
#      49     successful_files.add(new_name + extension)  # 更新为包含扩展名
#
# File ~/dev/miniconda3/envs/face-img-mac/lib/python3.8/shutil.py:780, in move(src, dst, copy_function)
#     778 sys.audit("shutil.move", src, dst)
#     779 real_dst = dst
# --> 780 if os.path.isdir(dst):
#     781     if _samefile(src, dst):
#     782         # We might be on a case insensitive filesystem,
#     783         # perform the rename anyway.
#     784         os.rename(src, dst)
#
# File ~/dev/miniconda3/envs/face-img-mac/lib/python3.8/genericpath.py:42, in isdir(s)
#      40 """Return true if the pathname refers to an existing directory."""
#      41 try:
# ---> 42     st = os.stat(s)
#      43 except (OSError, ValueError):
#      44     return False
#
# KeyboardInterrupt:

# %%
def custom_decimal_encoding(n):
    """
    将十进制数字转换为自定义编码，只使用指定的字符进行编码。

    参数:
    n (int): 待转换的十进制数字

    返回:
    str: 自定义编码结果
    """
    # 可使用的字符，排除了容易混淆的字符
    valid_chars = "2346789abcdefghijkmnpqrtuvwxyz"  # 剔除了容易混淆的字符：15os
    valid_chars_length = len(valid_chars)
    print(f"自定义编码字符长度: {valid_chars_length}")
    if n == 0:
        return valid_chars[0]

    result = ""
    while n > 0:
        remainder = n % valid_chars_length
        result = valid_chars[remainder] + result
        n //= valid_chars_length
    return result

# 测试 custom_decimal_encoding 方法
def test_custom_decimal_encoding():
    test_cases = list(range(34))
    # test_cases = [0, 1, 9, 10, 25, 26, 27, 31, 32, 33, 35, 50, 100, 1000, 12345, 987654321]
    for n in test_cases:
        encoded_str = custom_decimal_encoding(n)
        print(f"十进制数字 {n} 转换为自定义编码为: {encoded_str}")

test_custom_decimal_encoding()
# Out:
# 自定义编码字符长度: 30
# 十进制数字 0 转换为自定义编码为: 2
# 自定义编码字符长度: 30
# 十进制数字 1 转换为自定义编码为: 3
# 自定义编码字符长度: 30
# 十进制数字 2 转换为自定义编码为: 4
# 自定义编码字符长度: 30
# 十进制数字 3 转换为自定义编码为: 6
# 自定义编码字符长度: 30
# 十进制数字 4 转换为自定义编码为: 7
# 自定义编码字符长度: 30
# 十进制数字 5 转换为自定义编码为: 8
# 自定义编码字符长度: 30
# 十进制数字 6 转换为自定义编码为: 9
# 自定义编码字符长度: 30
# 十进制数字 7 转换为自定义编码为: a
# 自定义编码字符长度: 30
# 十进制数字 8 转换为自定义编码为: b
# 自定义编码字符长度: 30
# 十进制数字 9 转换为自定义编码为: c
# 自定义编码字符长度: 30
# 十进制数字 10 转换为自定义编码为: d
# 自定义编码字符长度: 30
# 十进制数字 11 转换为自定义编码为: e
# 自定义编码字符长度: 30
# 十进制数字 12 转换为自定义编码为: f
# 自定义编码字符长度: 30
# 十进制数字 13 转换为自定义编码为: g
# 自定义编码字符长度: 30
# 十进制数字 14 转换为自定义编码为: h
# 自定义编码字符长度: 30
# 十进制数字 15 转换为自定义编码为: i
# 自定义编码字符长度: 30
# 十进制数字 16 转换为自定义编码为: j
# 自定义编码字符长度: 30
# 十进制数字 17 转换为自定义编码为: k
# 自定义编码字符长度: 30
# 十进制数字 18 转换为自定义编码为: m
# 自定义编码字符长度: 30
# 十进制数字 19 转换为自定义编码为: n
# 自定义编码字符长度: 30
# 十进制数字 20 转换为自定义编码为: p
# 自定义编码字符长度: 30
# 十进制数字 21 转换为自定义编码为: q
# 自定义编码字符长度: 30
# 十进制数字 22 转换为自定义编码为: r
# 自定义编码字符长度: 30
# 十进制数字 23 转换为自定义编码为: t
# 自定义编码字符长度: 30
# 十进制数字 24 转换为自定义编码为: u
# 自定义编码字符长度: 30
# 十进制数字 25 转换为自定义编码为: v
# 自定义编码字符长度: 30
# 十进制数字 26 转换为自定义编码为: w
# 自定义编码字符长度: 30
# 十进制数字 27 转换为自定义编码为: x
# 自定义编码字符长度: 30
# 十进制数字 28 转换为自定义编码为: y
# 自定义编码字符长度: 30
# 十进制数字 29 转换为自定义编码为: z
# 自定义编码字符长度: 30
# 十进制数字 30 转换为自定义编码为: 32
# 自定义编码字符长度: 30
# 十进制数字 31 转换为自定义编码为: 33
# 自定义编码字符长度: 30
# 十进制数字 32 转换为自定义编码为: 34
# 自定义编码字符长度: 30
# 十进制数字 33 转换为自定义编码为: 36

# %%
def decimal_to_mixed_base(n):
    """将十进制数字转换为自定义基数的字母数字混合表示，基数由allowed_chars长度决定"""
    allowed_chars = "0123456789ABCDEFGHJKLMNPQRSTUVWXYZabcdefghjkmnpqrstuvwxyz"
    base = len(allowed_chars)
    result = ""
    
    # 处理负数
    is_negative = n < 0
    n = abs(n)
    
    while n > 0:
        n, remainder = divmod(n, base)
        result = allowed_chars[remainder] + result
    
    # 对于负数，在结果前添加负号
    if is_negative:
        result = '-' + result
    
    # 特殊处理n为0的情况
    elif not result:
        result = allowed_chars[0]
        
    return result

def test_decimal_to_mixed_base():
    print("测试正常数值:")
    print(f"0 -> {decimal_to_mixed_base(0)}")  # 应当输出 "0"
    print(f"21 -> {decimal_to_mixed_base(21)}")  # 应当输出 "T"
    print(f"22 -> {decimal_to_mixed_base(22)}")  # 应当输出 "10"
    print(f"45 -> {decimal_to_mixed_base(45)}")  # 应当输出 "21"
    
    print("\n测试大数值:")
    print(f"1000 -> {decimal_to_mixed_base(1000)}")  # 应当输出 "1F6"
    print(f"2222 -> {decimal_to_mixed_base(2222)}")  # 用于检验边界处理，实际输出会是自定义基数表示
    
    print("\n测试边缘情况:")
    print(f"-1 -> {decimal_to_mixed_base(-1)}")  # 应当输出 "-1"
    
    print("测试完成。")

# 运行测试
test_decimal_to_mixed_base()
# Out:
# 测试正常数值:
# 0 -> 0
# 21 -> M
# 22 -> N
# 45 -> n
#
# 测试大数值:
# 1000 -> HX
# 2222 -> ez
#
# 测试边缘情况:
# -1 -> -1
# 测试完成。

# %%
def decimal_to_custom_base(n):
    """将十进制数字转换为25进制，使用非容易混淆的字符编码"""
    characters = 'acdefhjkmnpqrtuvwxyz23478'
    base = len(characters)
    if n == 0:
        return characters[0]  # 将0映射到第一个字符'a'
    result = ""
    while n > 0:
        n, remainder = divmod(n, base)
        result = characters[remainder] + result
    return result

# 测试函数
def test_decimal_to_custom_base():
    test_cases = [
        (0, "a"),
        (1, "c"),
        (25, "ca"),
        (50, "ec"),
        (75, "kc"),
        (100, "rc"),
        (500, "trc"),
        (1000, "euc"),
        (1234, "mqc")
    ]

    for number, expected in test_cases:
        result = decimal_to_custom_base(number)
        assert result == expected, f"对于输入 {number}, 期望得到 '{expected}', 但实际得到 '{result}'"
        print(f"输入: {number}, 输出: {result}, 预期: {expected}")

    print("所有测试用例均通过")

# 运行测试函数
test_decimal_to_custom_base()
# Out:
# 输入: 0, 输出: a, 预期: a
# 输入: 1, 输出: c, 预期: c
# 输入: 25, 输出: ca, 预期: ca
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 35
#      32     print("所有测试用例均通过")
#      34 # 运行测试函数
# ---> 35 test_decimal_to_custom_base()
#
# Cell In[39], line 29, in test_decimal_to_custom_base()
#      27 for number, expected in test_cases:
#      28     result = decimal_to_custom_base(number)
# ---> 29     assert result == expected, f"对于输入 {number}, 期望得到 '{expected}', 但实际得到 '{result}'"
#      30     print(f"输入: {number}, 输出: {result}, 预期: {expected}")
#      32 print("所有测试用例均通过")
#
# AssertionError: 对于输入 50, 期望得到 'ec', 但实际得到 'da'
