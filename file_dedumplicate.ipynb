# %%
from PIL import Image
import numpy as np
import cv2
import os
from pathlib import Path
from imagehash import phash
from itertools import combinations
from typing import List, Set, Tuple

class ImageDescriptor:
    def __init__(self, unique_images: Set[Path], similar_groups: List[List[Path]]):
        self.unique_images = unique_images
        self.similar_groups = similar_groups

class HashDetector:
    def __init__(self, precision: int):
        self.precision = precision

    def detect(self, images: List[Path]) -> ImageDescriptor:
        print(f"Detecting duplicates using perceptual hash, precision: {self.precision}\nimages: {images}")
        hash_dict = {}
        for image_path in images:
            with Image.open(image_path) as img:
                img_hash = phash(img.convert("L").resize((self.precision, self.precision)))
                if img_hash in hash_dict:
                    hash_dict[img_hash].append(image_path)
                else:
                    hash_dict[img_hash] = [image_path]
        print(f"Found {len(hash_dict)} unique hashes")
        unique_images = set()
        similar_groups = []
        for paths in hash_dict.values():
            if len(paths) == 1:
                unique_images.add(paths[0])
            else:
                similar_groups.append(paths)
        print(f"Found {len(unique_images)} unique images, {len(similar_groups)} similar groups")
        return ImageDescriptor(unique_images, similar_groups)

class ORBDetector:
    def __init__(self, nfeatures: int, threshold: float):
        self.nfeatures = nfeatures
        self.threshold = threshold

    def detect(self, images: List[Path]) -> ImageDescriptor:
        keypoints_dict = {img: self._extract_features(img) for img in images}
        similar_groups = []
        unique_images = set(images)
        
        for img1, img2 in combinations(images, 2):
            kp1, des1 = keypoints_dict[img1]
            kp2, des2 = keypoints_dict[img2]
            if des1 is not None and des2 is not None:
                if self._match_features(des1, des2) > self.nfeatures * self.threshold:
                    similar_groups.append([img1, img2])
                    unique_images.remove(img1)
                    unique_images.remove(img2)

        return ImageDescriptor(unique_images, similar_groups)

    def _extract_features(self, image_path: Path):
        orb = cv2.ORB_create(self.nfeatures)
        img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
        return orb.detectAndCompute(img, None)

    def _match_features(self, des1, des2):
        bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
        matches = bf.match(des1, des2)
        return len(matches)

class ImageDeduplicator:
    def __init__(self, directory: str):
        self.directory = directory
        self.detectors = [
            HashDetector(8), HashDetector(16),
            ORBDetector(500, 0.7), ORBDetector(1000, 0.8)
        ]

    def deduplicate(self):
        images = [path for path in Path(self.directory).glob("*") if path.suffix.lower() in [".jpg", ".png"]]
        descriptor = ImageDescriptor(set(), [images])

        for detector in self.detectors:
            print(f"Processed with {type(detector).__name__}")
            new_descriptor = ImageDescriptor(descriptor.unique_images, [])
            for group in descriptor.similar_groups:
                result = detector.detect(group)
                descriptor.unique_images |= result.unique_images
                descriptor.similar_groups.extend(result.similar_groups)
            descriptor = new_descriptor
            print(f"unique count: {len(descriptor.unique_images)}")
        
        return descriptor

# Example usage
deduplicator = ImageDeduplicator("/Users/chenweichu/dev/data/test")
final_descriptor = deduplicator.deduplicate()
print(f"Final unique images count: {len(final_descriptor.unique_images)}")
# Out:
# Processed with HashDetector
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/af.jpg'), PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bk.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ag.jpg'), PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ae.jpg'), PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bi.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bh.jpg'), PosixPath('/Users/chenweichu/dev/data/test/as.jpg'), PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/aw.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bl.jpg'), PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bm.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg'), PosixPath('/Users/chenweichu/dev/data/test/y.jpg'), PosixPath('/Users/chenweichu/dev/data/test/at.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/n.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ac.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ab.jpg'), PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/o.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg'), PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ax.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/u.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/t.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ay.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ba.jpg'), PosixPath('/Users/chenweichu/dev/data/test/az.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/s.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/be.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/r.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ah.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/aj.jpg'), PosixPath('/Users/chenweichu/dev/data/ ...
# Found 51 unique hashes
# Found 29 unique images, 22 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bf.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/f.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/q.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ak.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cb.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bp.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bf.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/f.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/q.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ak.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cb.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bp.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bf.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/f.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/q.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ak.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cb.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bp.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bf.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/f.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/q.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ak.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cb.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bp.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/z.jpg'), PosixPath('/Users/chenweichu/dev/data/test/b.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/m.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cf.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/l.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ce.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bf.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aa.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bq.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bo.jpg'), PosixPath('/Users/chenweichu/dev/data/test/v.jpg'), PosixPath('/Users/chenweichu/dev/data/test/f.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/by.jpg'), PosixPath('/Users/chenweichu/dev/data/test/au.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bn.jpg'), PosixPath('/Users/chenweichu/dev/data/test/e.jpg'), PosixPath('/Users/chenweichu/dev/data/test/q.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/x.jpg'), PosixPath('/Users/chenweichu/dev/data/test/a.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ao.jpg'), PosixPath('/Users/chenweichu/dev/data/test/c.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bw.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/an.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bv.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bu.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ak.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bb.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cb.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/w.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bp.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ca.JPG'), PosixPath('/Users/chenweichu/dev/data/test/bs.JPG')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/k.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cd.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bd.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/aq.jpg'), PosixPath('/Users/chenweichu/dev/data/test/am.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/bj.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cg.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ap.jpg'), PosixPath('/Users/chenweichu/dev/data/test/d.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/j.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bc.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bt.jpg'), PosixPath('/Users/chenweichu/dev/data/test/al.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ai.jpg'), PosixPath('/Users/chenweichu/dev/data/test/g.jpg'), PosixPath('/Users/chenweichu/dev/data/test/cc.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/h.jpg'), PosixPath('/Users/chenweichu/dev/data/test/ar.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bx.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/i.jpg'), PosixPath('/Users/chenweichu/dev/data/test/bz.jpg'), PosixPath('/Users/chenweichu/dev/data/test/av.jpg')]
# Found 1 unique hashes
# Found 0 unique images, 1 similar groups
# Detecting duplicates using perceptual hash, precision: 8
# images: [PosixPath('/Users/chenweichu/dev/data/test/ad.jpg'), PosixPath('/Users/chenweichu/dev/data/test/br.jpg')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 97
#      95 # Example usage
#      96 deduplicator = ImageDeduplicator("/Users/chenweichu/dev/data/test")
# ---> 97 final_descriptor = deduplicator.deduplicate()
#      98 print(f"Final unique images count: {len(final_descriptor.unique_images)}")
#
# Cell In[11], line 87, in ImageDeduplicator.deduplicate(self)
#      85 new_descriptor = ImageDescriptor(descriptor.unique_images, [])
#      86 for group in descriptor.similar_groups:
# ---> 87     result = detector.detect(group)
#      88     descriptor.unique_images |= result.unique_images
#      89     descriptor.similar_groups.extend(result.similar_groups)
#
# Cell In[11], line 24, in HashDetector.detect(self, images)
#      22 for image_path in images:
#      23     with Image.open(image_path) as img:
# ---> 24         img_hash = phash(img.convert("L").resize((self.precision, self.precision)))
#      25         if img_hash in hash_dict:
#      26             hash_dict[img_hash].append(image_path)
#
# File ~/dev/miniconda3/envs/face-img-mac/lib/python3.8/site-packages/PIL/Image.py:941, in Image.convert(self, mode, matrix, dither, palette, colors)
#     889 def convert(
#     890     self,
#     891     mode: str | None = None,
#    (...)
#     895     colors: int = 256,
#     896 ) -> Image:
#     897     """
#     898     Returns a converted copy of this image. For the "P" mode, this
#     899     method translates pixels through the palette.  If mode is
#    (...)
#     938     :returns: An :py:class:`~PIL.Image.Image` object.
#     939     """
# --> 941     self.load()
#     943     has_transparency = "transparency" in self.info
#     944     if not mode and self.mode == "P":
#     945         # determine default mode
#
# File ~/dev/miniconda3/envs/face-img-mac/lib/python3.8/site-packages/PIL/ImageFile.py:291, in ImageFile.load(self)
#     288         raise OSError(msg)
#     290 b = b + s
# --> 291 n, err_code = decoder.decode(b)
#     292 if n < 0:
#     293     break
#
# KeyboardInterrupt:
